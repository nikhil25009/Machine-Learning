# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("D:\datascience\Cellphone.csv",error_bad_lines=False)
df
# Out:
# C:\Users\NIKHIL K\AppData\Local\Temp\ipykernel_10628\4128470540.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("D:\datascience\Cellphone.csv",error_bad_lines=False)
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# ...

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
# ...

# %%
df.drop(['Product_id','resoloution','ppi','cpu freq'],axis=1,inplace=True)

# %%
df
# Out:
#      Price  Sale  weight  cpu core  internal mem    ram  RearCam  Front_Cam  \
# 0     2357    10   135.0         8          16.0  3.000    13.00        8.0
# 1     1749    10   125.0         2           4.0  1.000     3.15        0.0
# 2     1916    10   110.0         4           8.0  1.500    13.00        5.0
# 3     1315    11   118.5         2           4.0  0.512     3.15        0.0
# 4     1749    11   125.0         2           4.0  1.000     3.15        0.0
# ..     ...   ...     ...       ...           ...    ...      ...        ...
# 156   3551  4638   178.0         4         128.0  6.000    12.00       16.0
# 157   3211  8016   170.0         4         128.0  6.000    20.00        8.0
# 158   3260  8809   150.0         8          64.0  4.000    20.00       20.0
# 159   3211  8946   170.0         4         128.0  6.000    20.00        8.0
# 160   2536  9807   202.0         8          16.0  3.000    21.50       16.0
#
#      battery  thickness
# 0       2610        7.4
# ...

# %%
df.shape
# Out:
# (161, 10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isna().sum()
# Out:
# Price           0
# Sale            0
# weight          0
# cpu core        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
df.dtypes
# Out:
# Price             int64
# Sale              int64
# weight          float64
# cpu core          int64
# internal mem    float64
# ram             float64
# RearCam         float64
# Front_Cam       float64
# battery           int64
# thickness       float64
# dtype: object

# %%
df.corr() #corr relation between coulmns
# Out:
#                  Price      Sale    weight  cpu core  internal mem       ram  \
# Price         1.000000  0.273263  0.144555  0.686811      0.776738  0.896915
# Sale          0.273263  1.000000  0.016114  0.069517      0.489308  0.373127
# weight        0.144555  0.016114  1.000000  0.216257      0.098849  0.149283
# cpu core      0.686811  0.069517  0.216257  1.000000      0.276251  0.483128
# internal mem  0.776738  0.489308  0.098849  0.276251      1.000000  0.875354
# ram           0.896915  0.373127  0.149283  0.483128      0.875354  1.000000
# RearCam       0.739538  0.292164 -0.029448  0.611353      0.451917  0.648073
# Front_Cam     0.675286  0.437233 -0.005971  0.586698      0.555733  0.647470
# battery       0.559946  0.120338  0.833783  0.459728      0.461506  0.541001
# thickness    -0.716773 -0.047991 -0.185262 -0.697935     -0.367412 -0.521074
#
#                RearCam  Front_Cam   battery  thickness
# Price         0.739538   0.675286  0.559946  -0.716773
# ...

# %%
sns.heatmap(df.corr(),annot=True) #heatmap representation of correlation
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df) #graphical representation of relation

# %%
sns.pairplot(df,kind="hist")

# %%
x=df.iloc[:,1:]
x
# Out:
#      Sale  weight  cpu core  internal mem    ram  RearCam  Front_Cam  battery  \
# 0      10   135.0         8          16.0  3.000    13.00        8.0     2610
# 1      10   125.0         2           4.0  1.000     3.15        0.0     1700
# 2      10   110.0         4           8.0  1.500    13.00        5.0     2000
# 3      11   118.5         2           4.0  0.512     3.15        0.0     1400
# 4      11   125.0         2           4.0  1.000     3.15        0.0     1700
# ..    ...     ...       ...           ...    ...      ...        ...      ...
# 156  4638   178.0         4         128.0  6.000    12.00       16.0     4080
# 157  8016   170.0         4         128.0  6.000    20.00        8.0     3400
# 158  8809   150.0         8          64.0  4.000    20.00       20.0     3000
# 159  8946   170.0         4         128.0  6.000    20.00        8.0     3400
# 160  9807   202.0         8          16.0  3.000    21.50       16.0     2700
#
#      thickness
# 0          7.4
# ...

# %%
y=df.iloc[:,:1]
y
# Out:
#      Price
# 0     2357
# 1     1749
# 2     1916
# 3     1315
# 4     1749
# ..     ...
# 156   3551
# 157   3211
# 158   3260
# 159   3211
# 160   2536
#
# [161 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#      Sale  weight  cpu core  internal mem    ram  RearCam  Front_Cam  battery  \
# 105   213    78.4         0         0.000  0.008      0.0        0.0     1100
# 28     25   146.0         4         8.000  1.000      5.0        5.0     1905
# 56     52   168.0         8        64.000  6.000     12.0        8.0     3350
# 119   378   118.0         4         4.000  0.512      5.0        2.0     1730
# 108   268   150.0         4        16.000  1.000     10.0        0.9     2200
# ..    ...     ...       ...           ...    ...      ...        ...      ...
# 133   599   112.0         8         8.000  1.000      8.0        8.0     1900
# 137   996   153.0         8        64.000  4.000     13.0       16.0     3200
# 72     93   310.0         8         8.000  2.000      5.0        2.0     4060
# 140  1224   102.9         0         0.256  0.128      1.3        0.0      950
# 37     35   489.0         4        16.000  2.000      5.0        2.0     7400
#
#      thickness
# 105       12.9
# ...

# %%
x_test
# Out:
#      Sale  weight  cpu core  internal mem    ram  RearCam  Front_Cam  battery  \
# 44     40   169.0         4        64.000  4.000    12.00        5.0     3500
# 47     41   144.0         8        32.000  3.000    20.70        5.1     2930
# 110   299    77.9         0         0.004  0.004     0.00        0.0      850
# 77    101   279.0         4         4.000  1.000     3.00        0.0     3240
# 158  8809   150.0         8        64.000  4.000    20.00       20.0     3000
# 11     16   161.0         8         4.000  1.000     5.00        0.0     2500
# 116   344   170.0         8        32.000  4.000    12.00       13.0     5000
# 35     32   151.0         8        32.000  2.000    16.00        5.0     3050
# 145  1862   179.0         4         8.000  1.000    13.00        8.0     2580
# 14     16   145.0         4        16.000  2.000    16.00        2.0     2800
# 78    101   156.0         8        16.000  2.000    13.00        5.0     2300
# ...

# %%
y_train
# Out:
#      Price
# 105    833
# 28    1390
# 56    3658
# 119   1734
# 108   1676
# ..     ...
# 133   2266
# 137   3116
# 72    2044
# 140    628
# 37    2124
#
# [112 rows x 1 columns]

# %%
y_test
# Out:
#      Price
# 44    2859
# 47    3316
# 110    754
# 77    1396
# 158   3260
# 11    2006
# 116   3287
# 35    2654
# 145   1921
# 14    2580
# 78    2714
# 99    1511
# 91    1831
# 19    1238
# 138   2409
# 75    2276
# 107   1676
# 81     791
# 85    1396
# 159   3211
# 102   1522
# 29    1950
# 39    2392
# 123   2001
# 95    1810
# 54    1984
# 5     2137
# 141    628
# 92    1831
# 16    2258
# 31    2977
# 53    3658
# 40    2124
# 93    1810
# 100   2343
# 42    1843
# 132   2466
# 51    1347
# 89    1302
# 154   2536
# 84    1646
# 33    2654
# 59    1741
# 73    3116
# 111   2975
# 66    2746
# 151   3055
# 12    2174
# 58    1989

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
import numpy as np
MinMaxScaler=preprocessing.MinMaxScaler()
x_train=MinMaxScaler.fit_transform(x_train)
x_test=MinMaxScaler.fit_transform(x_test)
print(x_test)
# Out:
# [[3.13409447e-03 2.43498818e-01 5.00000000e-01 5.00000000e-01
#   6.66444296e-01 5.58139535e-01 2.50000000e-01 4.09090909e-01
#   2.08955224e-01]
#  [3.24602642e-03 1.84397163e-01 1.00000000e+00 2.50000000e-01
#   4.99666444e-01 9.62790698e-01 2.55000000e-01 3.22727273e-01
#   1.34328358e-01]
#  [3.21244683e-02 2.81323877e-02 0.00000000e+00 3.12500000e-05
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 7.57575758e-03
#   5.44776119e-01]
#  [9.96194314e-03 5.03546099e-01 5.00000000e-01 3.12500000e-02
#   1.66110740e-01 1.39534884e-01 0.00000000e+00 3.69696970e-01
#   2.91044776e-01]
#  [9.84665323e-01 1.98581560e-01 1.00000000e+00 5.00000000e-01
#   6.66444296e-01 9.30232558e-01 1.00000000e+00 3.33333333e-01
#   1.26865672e-01]
#  [4.47727782e-04 2.24586288e-01 1.00000000e+00 3.12500000e-02
#   1.66110740e-01 2.32558140e-01 0.00000000e+00 2.57575758e-01
#   2.83582090e-01]
#  [3.71614059e-02 2.45862884e-01 1.00000000e+00 2.50000000e-01
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# C:\Users\NIKHIL K\AppData\Local\Temp\ipykernel_10628\1501409613.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train,y_train)
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([2959.5, 2836.4,  759.5, 1656.3, 3116.6, 1874.2, 2829. , 2669.6,
#        1852.8, 2329.4, 2610.1, 1713.9, 1656.9, 1519.5, 2492. , 2601.7,
#        2003.7,  799.4, 1656.3, 3662.8, 1594.2, 1912.7, 2725.9, 2050.1,
#        1854.5, 1854.2, 2236.7,  657.4, 1656.9, 2089.6, 2827.7, 3558.4,
#        2194. , 1854.5, 2265.4, 1688. , 2486.9, 1508.7, 1480.9, 2781.4,
#        1567. , 2669.6, 1517.9, 2969. , 2844.3, 3118. , 3618. , 2246.6,
#        2278.8])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9048379611310668

# %%
plt.scatter(y_test,y_pred)
